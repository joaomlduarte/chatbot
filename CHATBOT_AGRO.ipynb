# %% [markdown]
# <a href="https://colab.research.google.com/github/joaomlduarte/chatbot/blob/main/CHATBOT_AGRO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Instalação das bibliotecas
! pip install -q llama-index llama-index-readers-file llama-index-llms-google-genai llama-index-embeddings-google-genai

# %%
# !pip install nbformat==5.10.4 nbconvert==7.16.6

# %%
import nbformat
import nbconvert

print("nbformat:", nbformat.__version__)
print("nbconvert:", nbconvert.__version__)
# Out:
# nbformat: 5.10.4
# nbconvert: 7.16.6

# %%
# Rode esta célula antes de usar o Gemini com LlamaIndex
# %pip install -q nest-asyncio
import nest_asyncio
nest_asyncio.apply()
import os
from google.colab import userdata
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding
from llama_index.core import Settings

# Pega a variável de ambiente
os.environ['aula07_chatbot'] = userdata.get('aula07_chatbot')
api = os.environ['aula07_chatbot']

# %%
# Cria a variável chamada llm
llm = GoogleGenAI(
    model='gemini-2.5-flash-lite',
    api_key=api
)

Settings.llm = llm

# %%
from google.colab import files
import os
os.makedirs('/contents/documentos', exist_ok=True)
print('Pasta criada em /content/documentos')
# Out:
# Pasta criada em /content/documentos

# %%
# Leitura dos arquivos
from llama_index.core import SimpleDirectoryReader
documentos = SimpleDirectoryReader(input_dir='/content/documentos')

# %%
docs = documentos.load_data()
print(f'Quantidade de documentos carregados {len(docs)}')
# Out:
# WARNING:pypdf._reader:Ignoring wrong pointing object 6 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 8 0 (offset 0)
# WARNING:pypdf._reader:Ignoring wrong pointing object 11 0 (offset 0)
# Quantidade de documentos carregados 3

# %%
# Exibindo os metadados do documento
print(docs[0].get_metadata_str())
# Out:
# page_label: 1
# file_name: doc_info_agricultura.pdf
# file_path: /content/documentos/doc_info_agricultura.pdf
# file_type: application/pdf
# file_size: 30901
# creation_date: 2026-04-01
# last_modified_date: 2026-04-01

# %%
from llama_index.core import node_parser
# Quebrando o documento em pedaçõs (nodes)
#importando a biblioteca
from llama_index.core.node_parser import SentenceSplitter
node_parser=SentenceSplitter(chunk_size=1200) # Tamanho da divisão
# Fazer a divisão do documento carregado com base no chunk size
nodes = node_parser.get_nodes_from_documents(docs,show_progress = True)
print(f'Quantidade de nodes gerados: {len(nodes)}')
# Out:
# Parsing nodes:   0%|          | 0/3 [00:00<?, ?it/s]
# Quantidade de nodes gerados: 3

# %%
# Configurando o LLM Gemini e o modelo de embeddings
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.embeddings.google_genai import GoogleGenAIEmbedding
from llama_index.core import Settings

llm = GoogleGenAI(
    model = 'gemini-2.5-flash-lite',
    api_key = api
)

embed_model = GoogleGenAIEmbedding(
    model = 'gemini-embedding-001',
    api_key = api
)

Settings.llm = llm
Settings.embed_model = embed_model
print('LLM e embeddings configurados')
# Out:
# LLM e embeddings configurados

# %%
from llama_index.core import VectorStoreIndex
index = VectorStoreIndex(nodes,embed_model=embed_model)
print('Indice criado com sucesso')
# Out:
# Indice criado com sucesso

# %%
from llama_index.core.base.embeddings.base import similarity
# Realizando consultas no chatbot
# Query engine realiza consulta simples no documento
query_engine = index.as_query_engine(llm=llm, similarity_top_k=1)
response = query_engine.query('Quais são os tipos de fertilizantes?')
print(response)
# Out:
# Os fertilizantes podem ser orgânicos, químicos ou de liberação controlada. Fertilizantes orgânicos incluem esterco, húmus de minhoca, farinha de ossos e restos vegetais. Fertilizantes químicos são compostos sintéticos como NPK, ureia, superfosfato e cloreto de potássio. Fertilizantes de liberação controlada liberam nutrientes gradualmente no solo.

# %%
from llama_index.core.memory import ChatSummaryMemoryBuffer
memory = ChatSummaryMemoryBuffer(llm=llm,token_limit=256)
chat_engine= index.as_chat_engine(
    chat_mode = 'context',
    llm = llm,
    memory = memory,
    system_prompt=(
        'Você é especialista em agricultura. Sua função é dar os melhores conselhos que puder para o agricultor de uma maneira simpática e natural'
    )
)

# %%
response = chat_engine.chat('Você pode me dar detalhes sobre o melhor solo para plantio?')
print(response.response)
# Out:
# Olá! Que bom que você se preocupa com o solo, ele é a base de tudo na agricultura! 😊
#
# Para te dar a melhor orientação sobre o "melhor solo", preciso entender um pouquinho mais sobre o que você pretende plantar. Cada cultura tem suas preferências, sabe?
#
# Mas, de forma geral, podemos dizer que um solo ideal para o plantio é aquele que:
#
# *   **Tem boa drenagem:** Isso significa que a água não fica empoçada, o que é ruim para as raízes.
# *   **Retém a umidade na medida certa:** Nem seco demais, nem encharcado. As plantas precisam de água disponível.
# *   **É bem aerado:** As raízes precisam respirar! Um solo compactado dificulta isso.
# *   **É rico em nutrientes:** Essencial para o desenvolvimento saudável das plantas.
# *   **Tem um pH adequado:** O pH ideal varia para cada cultura, mas geralmente fica entre 5,5 e 7,0.
#
# **Falando em tipos de solo, temos alguns mais comuns:**
#
# *   **Solo Arenoso:** Drena muito rápido e perde nutrientes com facilidade. Para melhorar, a gente adiciona bastante matéria orgânica e irriga com mais frequência.
# *   **Solo Argiloso:** Ele segura muita água e pode ficar bem compactado. Para ajudar, a gente trabalha na aeração e pode até misturar um pouco de areia para melhorar a drenagem.
# *   **Solo Calcário:** Geralmente tem um pH mais alto e pode ter dificuldade em fornecer alguns micronutrientes. A gente corrige com adubação orgânica e fertilizantes que ajudam a equilibrar o pH.
#
# **Para saber exatamente o que o seu solo precisa, o ideal é fazer uma análise de solo.** Com ela, você descobre o pH, a umidade e quais nutrientes estão faltando. Assim, a gente pode corrigir e adubar na medida certa para a sua cultura!
#
# Me diga, o que você está pensando em plantar? Assim posso te dar dicas mais específicas! 😉

# %%
memory.get()
# Out:
# [ChatMessage(role=<MessageRole.SYSTEM: 'system'>, additional_kwargs={}, blocks=[TextBlock(block_type='text', text='user: Eu quero plantar milho.\n\nassistant: Ótima escolha! O milho é uma cultura que se adapta bem a diversos tipos de solo, mas ele tem suas preferências para um desenvolvimento ideal.\n\nPara o plantio de milho, o solo ideal é aquele que combina as características que mencionei antes, mas com um foco especial em:\n\n*   **Boa Drenagem e Aeração:** O milho não gosta de "pé molhado". Um solo que drena bem evita o apodrecimento das raízes e permite que elas respirem. Solos muito argilosos e compactados podem ser um problema se não forem corrigidos.\n*   **Boa Retenção de Umidade:** Apesar de precisar de boa drenagem, o milho é uma planta que consome bastante água, especialmente nas fases de espigamento e enchimento de grãos. Um solo que consegue reter umidade na medida certa é fundamental para evitar estresse hídrico.\n*   **Rico em Nutrientes:** O milho é uma planta "exigente" em nutrientes, principalmente nitrogênio, fósforo e potássio. Um solo com boa fertilidade natural ou bem adubado fará toda a diferença na produtividade.\n*   **pH Adequado:** O pH ideal para o milho geralmente fica entre **5,5 e 7,0**. Dentro dessa faixa, os nutrientes ficam mais disponíveis para a planta. Se o pH estiver muito ácido (abaixo de 5,5), pode ser necessário fazer uma calagem para corrigir.\n\n**Considerando os tipos de solo que falamos:**\n\n*   **Solo Arenoso:** Pode ser usado para milho, mas exigirá mais atenção com a irrigação e a adubação, pois ele perde nutrientes e água rapidamente. A adição de matéria orgânica é crucial para melhorar a retenção de água e nutrientes.\n*   **Solo Argiloso:** Se bem manejado, pode ser excelente para o milho, pois tem boa capacidade de reter água e nutrientes. O segredo é garantir a aeração e a drenagem, evitando o excesso de compactação. A incorporação de matéria orgânica e, em alguns casos, a aração e gradagem podem ajudar.\n*   **Solo Calcário:** Se o pH estiver muito alto, pode haver deficiência de micronutrientes como zinco e ferro. A adubação com esses micronutrientes e o uso de matéria orgânica podem ajudar a equilibrar a disponibilidade.\n\n**Recomendação para o seu plantio de milho:**\n\n1.  **Análise de Solo:** Se você ainda não fez, é o passo mais importante! Ela vai te dizer exatamente o pH, a quantidade de matéria orgânica e os níveis de nutrientes (N, P, K, etc.) no seu solo. Com esses dados, você saberá exatamente quais correções e adubações são necessárias.\n2.  **Matéria Orgânica:** Independentemente do tipo de solo, adicionar composto orgânico, esterco curtido ou outros materiais orgânicos é sempre benéfico. Isso melhora a estrutura do solo, a retenção de água e a disponibilidade de nutrientes.\n3.  **Adubação:** Com base na análise de solo e nas necessidades do milho, faça uma adubação equilibrada. O nitrogênio é especialmente importante para o milho.\n4.  **Manejo da Água:** Garanta que o solo tenha boa drenagem, mas também planeje a irrigação, se necessário, para os períodos de maior demanda de água.\n\nVocê já fez alguma análise de solo na área onde pretende plantar o milho? Isso nos ajudaria a refinar ainda mais as recomendações! 😉')])]

# %%
# Reset do chat
chat_engine.reset()
print('Chat resetado')
# Out:
# Chat resetado

# %%
! pip install -q ipywidgets

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output
from google.genai.errors import ClientError

# %%
import ipywidgets as widgets
from IPython.display import display, Markdown, clear_output

# Se ClientError vier de alguma lib específica, mantenha o import correto.
# Exemplo:
# from google.api_core.exceptions import ClientError

# Área de saída do chat
chat_output = widgets.Output(
    layout={
        "border": "1px solid #ccc",
        "padding": "10px",
        "height": "700px",
        "overflow_y": "auto"
    }
)

# Área de entrada do chat
input_box = widgets.Text(
    placeholder="Digite sua pergunta sobre solos",
    description="Pergunta:",
    layout=widgets.Layout(width="80%")
)

# Botões
send_button = widgets.Button(
    description="Enviar",
    button_style="info"   # troquei de primary para info
)

clear_button = widgets.Button(
    description="Limpar",
    button_style="warning"
)

# Histórico simples
history = []

def responder(pergunta):
    try:
        response = chat_engine.chat(pergunta)
        return getattr(response, "response", str(response))

    except ClientError as e:
        erro = str(e)

        if "429" in erro or "RESOURCE_EXHAUSTED" in erro:
            try:
                retriever = index.as_retriever(similarity_top_k=1)
                nodes = retriever.retrieve(pergunta)

                if nodes:
                    partes = []
                    for i, node in enumerate(nodes, 1):
                        texto = getattr(node, "text", str(node))
                        partes.append(f"**Trecho {i}:**\n\n{texto[:500]}")

                    return (
                        "A API Gemini atingiu o limite no momento. "
                        "Encontrei estes trechos locais:\n\n"
                        + "\n\n---\n\n".join(partes)
                    )

                return "A API Gemini atingiu o limite e não encontrei trechos locais relevantes."

            except Exception as erro_retriever:
                return f"A API Gemini atingiu o limite e houve erro ao buscar trechos locais: {erro_retriever}"

        return f"Erro na API: {erro}"

    except Exception as e:
        return f"Erro inesperado: {e}"

# Função para renderizar o chat
def render_chat():
    with chat_output:
        clear_output(wait=True)
        display(Markdown("## Assistente Agricultor"))

        if not history:
            display(Markdown("_Nenhuma mensagem ainda._"))

        for role, content in history:
            if role == "user":
                display(Markdown(f"**Você:** {content}"))
            else:
                display(Markdown(f"**Assistente Agricultor:** {content}"))

# Evento de envio
def on_send(_):
    pergunta = input_box.value.strip()
    if not pergunta:
        return

    history.append(("user", pergunta))
    resposta = responder(pergunta)
    history.append(("assistant", resposta))

    input_box.value = ""
    render_chat()

# Evento de limpar
def on_clear(_):
    history.clear()
    try:
        chat_engine.reset()
    except Exception:
        pass
    render_chat()

send_button.on_click(on_send)
clear_button.on_click(on_clear)
input_box.on_submit(lambda _: on_send(None))

display(widgets.VBox([
    chat_output,
    widgets.HBox([input_box, send_button, clear_button])
]))

render_chat()
# Out:
# VBox(children=(Output(layout=Layout(border='1px solid #ccc', height='700px', overflow_y='auto', padding='10px'…
